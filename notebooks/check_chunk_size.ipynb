# %%
#!/usr/bin/env python3
"""
Quick check: How many chunks exceed 512 tokens?
This determines if all-minilm is safe or if nomic-embed-text is needed.
"""

import json
from pathlib import Path
import sys

# Add project root to path
# project_"""  """root = Path(__file__).parent.parent.parent
# sys.path.insert(0, str(project_root))

from src.utils.config import get_config

def estimate_tokens(text):
    """
    Rough token estimation (4 chars ≈ 1 token)
    Good enough for decision-making.
    """
    return len(text) // 4

def check_chunk_lengths():
    config = get_config()
    
    print("=" * 70)
    print("CHUNK TOKEN LENGTH ANALYSIS")
    print("=" * 70)
    
    # Check all chunk files
    chunk_files = [
        ("Books", config.FILE_BOOK_CHUNKS),
        ("Wiki Chronology", config.FILE_WIKI_CHUNKS_CHRONOLOGY),
        ("Wiki Characters", config.FILE_WIKI_CHUNKS_CHARACTER),
        ("Wiki Chapter Summaries", config.FILE_WIKI_CHUNKS_CHAPTER_SUMMARY),
        ("Wiki Concepts", config.FILE_WIKI_CHUNKS_CONCEPT),
    ]
    
    all_lengths = []
    total_chunks = 0
    over_512 = 0
    
    for name, filepath in chunk_files:
        if not filepath.exists():
            print(f"\n⚠️  {name}: File not found - {filepath}")
            continue
            
        lengths = []
        with open(filepath) as f:
            for line in f:
                chunk = json.loads(line)
                token_estimate = estimate_tokens(chunk['text'])
                lengths.append(token_estimate)
                all_lengths.append(token_estimate)
                total_chunks += 1
                if token_estimate > 512:
                    over_512 += 1
        
        avg = sum(lengths) / len(lengths)
        max_len = max(lengths)
        over_512_here = sum(1 for l in lengths if l > 512)
        
        print(f"\n📁 {name}:")
        print(f"   Chunks: {len(lengths)}")
        print(f"   Average: {avg:.0f} tokens")
        print(f"   Max: {max_len} tokens")
        print(f"   Over 512: {over_512_here} ({over_512_here/len(lengths)*100:.1f}%)")
    
    # Overall statistics
    print("\n" + "=" * 70)
    print("OVERALL STATISTICS")
    print("=" * 70)
    
    all_lengths.sort()
    avg = sum(all_lengths) / len(all_lengths)
    median = all_lengths[len(all_lengths) // 2]
    
    print(f"\nTotal chunks: {total_chunks:,}")
    print(f"Average: {avg:.0f} tokens")
    print(f"Median: {median} tokens")
    print(f"Max: {max(all_lengths)} tokens")
    
    print(f"\n🚨 CRITICAL FINDING:")
    print(f"   Chunks >512 tokens: {over_512:,} ({over_512/total_chunks*100:.1f}%)")
    
    # Distribution
    print(f"\n📊 DISTRIBUTION:")
    ranges = [
        (0, 256, "0-256 tokens"),
        (256, 512, "256-512 tokens"),
        (512, 1024, "512-1024 tokens ⚠️"),
        (1024, 2000, "1024-2000 tokens ⚠️⚠️"),
    ]
    
    for start, end, label in ranges:
        count = sum(1 for t in all_lengths if start <= t < end)
        pct = count/total_chunks*100
        bar = "█" * int(pct / 2)
        print(f"   {label:<25} {count:>6,} ({pct:>5.1f}%) {bar}")
    
    # Recommendation
    print("\n" + "=" * 70)
    print("RECOMMENDATION")
    print("=" * 70)
    
    pct_over_512 = (over_512/total_chunks) * 100
    
    if pct_over_512 > 20:
        print("\n❌ DO NOT USE all-minilm")
        print(f"   Reason: {pct_over_512:.1f}% of chunks exceed 512 tokens")
        print(f"   Impact: {over_512:,} chunks will be TRUNCATED")
        print(f"   Loss: Significant WoT lore will be lost")
        print("\n✅ USE nomic-embed-text instead")
        print("   - Handles chunks up to 8,192 tokens")
        print("   - No information loss")
        print("   - Worth the extra 11 hours")
        
    elif pct_over_512 > 10:
        print("\n⚠️ CAUTION with all-minilm")
        print(f"   Reason: {pct_over_512:.1f}% of chunks exceed 512 tokens")
        print(f"   Impact: {over_512:,} chunks will be truncated")
        print("\n💡 OPTIONS:")
        print("   A) Use nomic-embed-text (safer, no truncation)")
        print("   B) Re-chunk to keep all under 512 tokens, then use all-minilm")
        print("   C) Accept 10-20% truncation loss, use all-minilm (risky)")
        
    else:
        print("\n✅ all-minilm is SAFE to use")
        print(f"   Reason: Only {pct_over_512:.1f}% exceed 512 tokens")
        print(f"   Impact: Minimal truncation ({over_512:,} chunks)")
        print(f"   Benefit: 11 hours faster than nomic-embed-text")
        print("\n   Go ahead with all-minilm!")
    
    print("\n" + "=" * 70)

if __name__ == "__main__":
    try:
        check_chunk_lengths()
    except Exception as e:
        print(f"\n❌ Error: {e}")
        import traceback
        traceback.print_exc()
# Out:
# ======================================================================
# CHUNK TOKEN LENGTH ANALYSIS
# ======================================================================
#
# 📁 Books:
#    Chunks: 7374
#    Average: 908 tokens
#    Max: 1015 tokens
#    Over 512: 7058 (95.7%)
#
# 📁 Wiki Chronology:
#    Chunks: 26
#    Average: 398 tokens
#    Max: 1464 tokens
#    Over 512: 5 (19.2%)
#
# 📁 Wiki Characters:
#    Chunks: 10745
#    Average: 56 tokens
#    Max: 1985 tokens
#    Over 512: 64 (0.6%)
#
# 📁 Wiki Chapter Summaries:
#    Chunks: 756
#    Average: 742 tokens
#    Max: 1989 tokens
#    Over 512: 516 (68.3%)
#
# 📁 Wiki Concepts:
#    Chunks: 5872
#    Average: 111 tokens
#    Max: 1929 tokens
#    Over 512: 167 (2.8%)
#
# ======================================================================
# OVERALL STATISTICS
# ======================================================================
#
# Total chunks: 24,773
# Average: 344 tokens
# Median: 89 tokens
# Max: 1989 tokens
#
# 🚨 CRITICAL FINDING:
#    Chunks >512 tokens: 7,810 (31.5%)
#
# 📊 DISTRIBUTION:
#    0-256 tokens              15,840 ( 63.9%) ███████████████████████████████
#    256-512 tokens             1,122 (  4.5%) ██
#    512-1024 tokens ⚠️         7,606 ( 30.7%) ███████████████
#    1024-2000 tokens ⚠️⚠️        205 (  0.8%)
#
# ======================================================================
# RECOMMENDATION
# ======================================================================
#
# ❌ DO NOT USE all-minilm
#    Reason: 31.5% of chunks exceed 512 tokens
#    Impact: 7,810 chunks will be TRUNCATED
#    Loss: Significant WoT lore will be lost
#
# ✅ USE nomic-embed-text instead
#    - Handles chunks up to 8,192 tokens
#    - No information loss
#    - Worth the extra 11 hours
#
# ======================================================================

# %%
from src.retrieval.pass_17_uses_this_vector_store import VectorStoreManager
from src.utils.config import get_config

m = VectorStoreManager(get_config())
r = m.query('balefire', 'magic', k=10)

for i in range(min(5, len(r))):
    print(f"{i+1}. {r[i]['text'][:100]}...")
    print()
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[1], line 5
#       2 from src.utils.config import get_config
#       4 m = VectorStoreManager(get_config())
# ----> 5 r = m.query('balefire', 'magic', k=10)
#       7 for i in range(min(5, len(r))):
#       8     print(f"{i+1}. {r[i]['text'][:100]}...")
#
# File ~\Documents\_AI\dragon-codex\src\retrieval\pass_16_uses_this_vector_store.py:224, in VectorStoreManager.query(self, query_text, collection_name, k, max_book)
#     217 def query(self,
#     218         query_text: str,
#     219         collection_name: str,
#     220         k: int = 10,
#     221         max_book: Optional[int] = None) -> List[Dict]:
#     222     """Query with post-filtering for temporal"""
# --> 224     collection = self.client.get_collection(name=collection_name)
#     225     query_embedding = self.embed_text(query_text)
#     227     # Get more results than needed (for filtering)
#
# File c:\Users\victor.diaz\AppData\Local\miniconda3\envs\dragon\Lib\site-packages\chromadb\api\client.py:218, in Client.get_collection(self, name, id, embedding_function, data_loader)
#     208 @override
#     209 def get_collection(
#     210     self,
#    (...)    216     data_loader: Optional[DataLoader[Loadable]] = None,
#     217 ) -> Collection:
# --> 218     return self._server.get_collection(
#     219         id=id,
#     220         name=name,
#     221         embedding_function=embedding_function,
#     222         data_loader=data_loader,
#     223         tenant=self.tenant,
#     224         database=self.database,
#     225     )
#
# File c:\Users\victor.diaz\AppData\Local\miniconda3\envs\dragon\Lib\site-packages\chromadb\telemetry\opentelemetry\__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File c:\Users\victor.diaz\AppData\Local\miniconda3\envs\dragon\Lib\site-packages\chromadb\api\segment.py:244, in SegmentAPI.get_collection(self, name, id, embedding_function, data_loader, tenant, database)
#     242 if id is None and name is None or (id is not None and name is not None):
#     243     raise ValueError("Name or id must be specified, but not both")
# --> 244 existing = self._sysdb.get_collections(
#     245     id=id, name=name, tenant=tenant, database=database
#     246 )
#     248 if existing:
#     249     return Collection(
#     250         client=self,
#     251         id=existing[0]["id"],
#    (...)    257         database=existing[0]["database"],
#     258     )
#
# File c:\Users\victor.diaz\AppData\Local\miniconda3\envs\dragon\Lib\site-packages\chromadb\telemetry\opentelemetry\__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File c:\Users\victor.diaz\AppData\Local\miniconda3\envs\dragon\Lib\site-packages\chromadb\db\mixins\sysdb.py:435, in SqlSysDB.get_collections(self, id, topic, name, tenant, database, limit, offset)
#     433 with self.tx() as cur:
#     434     sql, params = get_sql(q, self.parameter_format())
# --> 435     rows = cur.execute(sql, params).fetchall()
#     436     by_collection = groupby(rows, lambda r: cast(object, r[0]))
#     437     collections = []
#
# OperationalError: no such column: collections.topic

# %%
import requests

response = requests.post(
    "http://localhost:11434/api/embeddings",
    json={
        "model": "nomic-embed-text",  # Replace with actual model name
        "prompt": "test text"
    }
)

print(f"Status: {response.status_code}")
print(f"Response: {response.text}")
# Out:
# Status: 200
# Response: {"embedding":[0.49240708351135254,-0.616692841053009,-3.710094451904297,-0.6087756156921387,1.9103617668151855,-0.8515751957893372,0.5173655152320862,-0.1970754712820053,0.280231237411499,-0.5641685724258423,-0.3114444315433502,1.672110915184021,0.8428081274032593,0.4269160032272339,-1.5409306287765503,-1.1429648399353027,1.751835823059082,-1.1847422122955322,-0.9133931398391724,0.4924255907535553,0.6768071055412292,0.2322305142879486,-1.9192509651184082,-0.21293869614601135,1.7830898761749268,-0.1136506050825119,-1.6385924816131592,0.685033917427063,-1.2440330982208252,-0.578854501247406,0.5379506945610046,-0.7773053050041199,-0.09580922871828079,-0.9656651616096497,-0.8145878314971924,-0.22032709419727325,0.062421515583992004,1.1489791870117188,-0.9540960788726807,0.707647442817688,0.9509190320968628,0.1343558430671692,-1.285065770149231,-0.8553984761238098,1.8211205005645752,-0.3725104331970215,-0.7259283661842346,1.6568032503128052,0.5253516435623169,-1.0795460939407349,-0.755139946937561,-1.0183961391448975,0.9201903939247131,-0.630054771900177,1.2760659456253052,0.2046390026807785,-0.8375282287597656,-1.2850086688995361,0.08515860140323639,-0.6883410811424255,1.1989505290985107,1.6686097383499146,-2.8173277378082275,1.2410540580749512,1.2457807064056396,-1.8203545808792114,-0.8083258867263794,0.8006882667541504,-0.010785847902297974,0.389900803565979,1.237295150756836,0.6672638654708862,-0.03424207866191864,-0.07434332370758057,-1.1760072708129883,-2.1180596351623535,-1.0376626253128052,-0.22518011927604675,-0.1652933955192566,0.39874961972236633,1.2213422060012817,-0.47257620096206665,1.530137300491333,0.8992961049079895,1.9470977783203125,-0.44432884454727173,-0.46191829442977905,-0.9194918870925903,-1.5114519596099854,1.8297301530838013,0.7054988145828247,1.0635080337524414,-0.004065481945872307,0.4357199966907501,-1.0053410530090332,0.6134979724884033,-0.4297860860824585,0.11535756289958954,0.21238869428634644,-0.6989187002182007,-0.3165421187877655,-0.08554413169622421,0.6127312779426575,-0.7092627882957458,0.01613914594054222,0.5430842638015747,-0.3329722583293915,-0.3227338492870331,-1.1146061420440674,-0.3637837767601013,-0.47495582699775696,1.0805964469909668,-0.8824188709259033,-0.3520984351634979,-0.4845728874206543,-0.2408045530319214,0.5733183026313782,-0.36044636368751526,0.13866108655929565,-0.5756822228431702,-0.0904330164194107,0.8503048419952393,-0.04009890928864479,0.8556047677993774,-0.9294190406799316,0.4859769642353058,-0.516460120677948,1.417814016342163,0.6063413023948669,-0.6279542446136475,-0.32894882559776306,0.3730747103691101,-0.6225477457046509,-0.47203588485717773,-0.2123045176267624,1.4711127281188965,-0.4445033073425293,-0.000007841736078262329,-0.3783283829689026,-0.4783394932746887,-0.263943076133728,-0.25067782402038574,-0.04348839446902275,0.313910573720932,0.05632656812667847,-1.1181763410568237,0.28296083211898804,-0.4758709669113159,0.47070199251174927,-0.6541364789009094,0.3553253412246704,-0.7033362984657288,1.2152584791183472,0.5167561173439026,0.5317715406417847,0.2108565717935562,1.3611845970153809,-0.45476606488227844,-0.1711473912000656,1.254059076309204,0.5486320853233337,0.04372486472129822,-0.7948064804077148,-0.11862390488386154,-0.6715630292892456,-1.0010336637496948,-0.690727710723877,2.015564441680908,1.5716876983642578,0.06498878449201584,-1.6005504131317139,-1.0869349241256714,1.0842198133468628,-0.3790857493877411,-0.8105272054672241,-0.7793904542922974,0.0524836927652359,-0.756344199180603,0.7475359439849854,0.42846524715423584,-0.053482647985219955,-0.9416971802711487,0.8867225646972656,0.043905820697546005,-0.6309070587158203,-0.5894796848297119,-0.5138337016105652,-0.5762085318565369,-0.24151873588562012,0.21172332763671875,-0.9916533827781677,-0.974915087223053,-2.014488458633423,-1.0283856391906738,-0.2929900884628296,-1.6117150783538818,0.6455355882644653,0.6435306668281555,0.7989392280578613,0.2807586193084717,-0.6650503873825073,-0.05587983876466 ...

# %%
import json
from src.utils.config import get_config

config = get_config()

with open(config.FILE_WIKI_CONCEPT, 'r', encoding='utf-8') as f:
    wiki_concepts = json.load(f)

print(f"Type: {type(wiki_concepts)}")
print(f"Keys: {list(wiki_concepts.keys())[:10]}")
print(f"\nFirst entry:")
first_key = list(wiki_concepts.keys())[0]
print(f"Key: {first_key}")
print(f"Value: {wiki_concepts[first_key]}")
# Out:
# Type: <class 'dict'>
# Keys: ['1000_NE.txt', '978_NE.txt', '979_NE.txt', '998_NE.txt', '999_NE.txt', 'Abayan.txt', 'Abila.txt', "Abor'maseleine.txt", 'Abrishi.txt', 'Abunai.txt']
#
# First entry:
# Key: 1000_NE.txt
# Value: {'filename': '1000_NE.txt', 'page_type': 'CONCEPT', 'page_name': '1000 NE', 'metadata': {'page_id': 703, 'categories': ['Articles_that_need_to_be_wikified', 'Time', 'New_Era_chronology']}, 'sections': [{'level': 2, 'title': 'Categories', 'content': 'Articles_that_need_to_be_wikified, New_Era_chronology, Time', 'subsections': []}, {'level': 2, 'title': 'Overview', 'content': 'Initial import from http://www.stevenac.net/wot/tl1000.htm and copyrighted by Steven Cooper. Used by permission, not GFDL.', 'subsections': []}], 'aliases': []}

# %%
import json
from src.utils.config import get_config

config = get_config()

with open(config.FILE_FILENAME_TO_CATEGORIES, 'r', encoding='utf-8') as f:
    category_mappings = json.load(f)

# Get all unique categories
all_categories = set()
for cats in category_mappings.values():
    all_categories.update(cats)

print(f"Total unique categories: {len(all_categories)}")
print("\nAll categories (sorted):")
for cat in sorted(all_categories):
    print(f"  {cat}")
# Out:
# Total unique categories: 650
#
# All categories (sorted):
#   A_Crown_of_Swords_chapter_summaries
#   A_Memory_of_Light_chapter_summaries
#   Accepted
#   Administrative_redirects
#   Advocates
#   Aelfinn_and_Eelfinn
#   Aelgar
#   Aelgar_(people)
#   Aes_Sedai
#   Aes_Sedai_(Age_of_Legends)
#   Aes_Sedai_(Free_Years)
#   Aes_Sedai_after_the_Breaking
#   Aes_Sedai_factions
#   Aes_Sedai_positions
#   Aethan_Dor
#   After_the_Breaking
#   Age_of_Legends
#   Age_of_Legends_(people)
#   Ages
#   Aiel
#   Aiel_(people)
#   Aiel_Waste
#   Aiel_clans
#   Aiel_culture
#   Aiel_septs
#   Aiel_warrior_societies
#   Ajah_Heads
#   Ajahs
#   Aldeshar_(people)
#   Alias_redirects
#   Aliases
#   All_books
#   Almoren
#   Almoren_(people)
#   Almoth_Plain
#   Altara
#   Altara_(people)
#   Amadicia
#   Amadicia_(people)
#   Amayar
#   Amayar_(people)
#   Amyrlin_Seats
#   Andor
#   Andor_(people)
#   Angreal
#   Animals
#   Antagonists
#   Apprentices
#   Arad_Doman
#   Arad_Doman_(people)
#   Arafel
#   Arafel_(people)
#   Aramaelle
#   Aramaelle_(people)
#   Aridhol
#   Aridhol_(people)
#   Articles_that_need_to_be_wikified
#   Articles_to_be_expanded
#   Artists
#   Asha'man
#   Asha'man_(rank)
#   Assistants
#   Atha'an_Miere
#   Atha'an_Miere_(people)
#   Atha'an_Miere_culture
#   Attendants
#   Authors
#   Ayyad
#   Baker_(possibly)s
#   Balefired
#   Band_of_the_Red_Hand
#   Bankers
#   Barbers
#   Bards
#   Battle_Cries
#   Battles
#   Bellfounders
#   Bent_Peak
#   Best_healers
#   Black_Ajah
#   Black_Cliffs
#   Black_Hills
#   Black_Hills_(people)
#   Black_Rock
#   Black_Water
#   Blacksmiths
#   Blademasters
#   Blue_Ajah
#   Boatmens
#   Book_glossaries
#   Book_redirects
#   Books
#   Bootmakers
#   Borderlands
#   Borderlands_(people)
#   Bouncers
#   Bound_to_the_Wheel
#   Brickmasons
#   Bridges
#   Broken_Cliff
#   Brown_Ajah
#   Builders
#   Buildings
#   Caembarin
#   Caembarin_(people)
#   Caemlyn
#   Caemlyn_Embassy
#   Cairhien
#   Cairhien_(people)
#   Cairhien_Academy
#   Cairhien_expedition
#   Calendars
#   Capitals
#   Cargomasters
#   Carpenters
#   Category_redirects
#   Cats
#   Cha_Faile
#   Chane_Rocks
#   Channelers
#   Chapter_disambiguations
#   Chapter_redirects
#   Chapter_summaries
#   Chapter_summaries_crown_of_swords
#   Character_Chronologies
#   Characters
#   Characters_named_after_fans
#   Chareen
#   Chief_Librarians
#   Children_of_the_Light
#   Chumai
#   Citation_needed
#   Cities
#   Cities_(Age_of_Legends)
#   Clan_chiefs
#   Cleanup
#   Clerks
#   Cobblers
#   Codarra
#   Cold_Peak
#   Comparison
#   Concepts
#   Constellation
#   Constellations
#   Constructs
#   Continents
#   Contradictions
#   Conventions
#   Cooks
#   Coopers
#   Cor_Darei
#   Coremanda
#   Coremanda_(people)
#   Cosaida
#   Council_of_Merchants
#   Council_of_Nine
#   Counsels_of_Far_Madding
#   Craftsmans
#   Crossroads_of_Twilight_chapter_summaries
#   Crowns_and_Regalia
#   Culture
#   Cutpurses
#   Da'covale
#   Da'shain_Aiel
#   Dal_Calain_(people)
#   Damane
#   Darkfriends
#   Darmovan_(people)
#   Daryne
#   Date_redirects
#   Dates
#   Deathwatch_Guards
#   Deceased
#   Deckmistresses
#   Dedicated
#   Degalle
#   Dhowlan_(people)
#   Dice
#   Disambiguation
#   Diseases
#   Dockmasters
#   Domai
#   Doomseers
#   Dorlan_Group
#   Dragonsworn
#   Dreadlords
#   Dreamers
#   Dreamwalkers
#   Duadhe_Mahdi'in
#   Dubious
#   Ebou_Dari_Stash
#   Eharon
#   Eharon_(people)
#   Elaida_a'Roihan's_White_Tower
#   Emperors
#   Empresses
#   Entertainers
#   Esandara_(people)
#   Essenia
#   Essenia_(people)
#   Ever_Victorious_Army
#   Exegetic
#   Extradimensional_entities
#   Eyes-and-ears
#   False_Dragons
#   Far_Aldazar_Din
#   Far_Dareis_Mai
#   Far_Madding
#   Far_Madding_(people)
#   Farashelle_(people)
#   Farm_Group
#   Farmers
#   Farriers
#   Fashion
#   Female
#   Ferrets
#   Ferrymasters
#   Fictitious_Characters
#   First_Age
#   First_Twelve_of_the_Atha'an_Miere
#   Firsts_of_Mayene
#   Fishers
#   Five_Great_Captains
#   Flags
#   Fletchers
#   Foods
#   Footmen
#   Foreseen_events
#   Foreseen_people
#   Forests
#   Foretellings
#   Former_Nations_of_the_New_Era
#   Forsaken
#   Fourth_Age
#   Gai'shain
#   Gamblers
#   Games
#   Gardeners
#   Gatekeepers
#   Gates
#   Generals
#   Geo-political_redirects
#   Geographical_features
#   Geographical_regions
#   Ghealdan
#   Ghealdan_(people)
#   Gleemen
#   Glossary
#   Glossary_Only
#   Goldsmiths
#   Goods
#   Goshien
#   Grammar_redirects
#   Gray_Ajah
#   Great_Cities
#   Green_Ajah
#   Green_Salts
#   Groups
#   Guards
#   Guardsmans
#   Gulfs_and_bays
#   Haido
#   Hama_N'dore
#   Head_servants
#   Headmistresses
#   Healers
#   Herbs_and_Medicines
#   Heroes_of_the_Horn
#   High_Nobility_of_Tear
#   High_Ranking_Aes_Sedai
#   High_Seats
#   Hills
#   Historians
#   Historical
#   Historical_nations
#   Historical_people
#   Historical_settlements
#   History
#   Hol_Cuchone_(people)
#   Holds
#   Holidays
#   Horses
#   Housewifes
#   Hunters_of_the_Horn
#   Illian
#   Illian_(people)
#   Illuminators
#   Imran
#   In-universe_content
#   Inclusion_redirects
#   Innkeepers
#   Inns
#   Inquisitors
#   Instruments
#   Inventors
#   Iron_Mountain
#   Islands
#   Islands_of_the_Atha'an_Miere
#   Items
#   Items_of_Power
#   Jaern_Rift
#   Jaramide
#   Jaramide_(people)
#   Jarra
#   Jenda
#   Jenn_Aiel
#   Jhirad
#   Jindo
#   Jumai
#   Kandor
#   Kandor_(people)
#   Keepers_of_the_Chronicles
#   Khodomar_(people)
#   Kings
#   Kinswomen
#   Knife_of_Dreams_chapter_summaries
#   Ladies
#   Languages
#   Laws_and_customs
#   Learners
#   Legends
#   Lensmakers
#   Librarians
#   List_pages
#   Living
#   Living_as_of_ACOS
#   Living_as_of_AMOL
#   Living_as_of_CCG
#   Living_as_of_COT
#   Living_as_of_GUIDE
#   Living_as_of_KOD
#   Living_as_of_LOC
#   Living_as_of_NS
#   Living_as_of_TDR
#   Living_as_of_TEOTW
#   Living_as_of_TFOH
#   Living_as_of_TGH
#   Living_as_of_TGS
#   Living_as_of_TOM
#   Living_as_of_TPOD
#   Living_as_of_TSASG
#   Living_as_of_TSR
#   Living_as_of_TWOTC
#   Living_as_of_WH
#   Locations
#   Logain's_followers
#   Lord_Captain
#   Lord_Captain_Commanders
#   Lord_of_Chaos_chapter_summaries
#   Lords
#   Low_Ranking_Aes_Sedai
#   Maids
#   Main_Series
#   Major_Houses_of_Andor
#   Malkier
#   Malkier_(people)
#   Manetheren
#   Manetheren_(people)
#   Mapmakers
#   Maps
#   Maps_of_Nations_and_Kingdoms
#   Maredo_(people)
#   Marriage
#   Marshes
#   Masenashar_(people)
#   Masons
#   Masters_of_the_Blades
#   Mayene
#   Mayene_(people)
#   Mayors_and_governors
#   Measurements
#   Men
#   Mera'din
#   Mercenaries
#   Merchants
#   Metaphysics
#   Miagoma
#   Middle_Ranking_Aes_Sedai
#   Midlander
#   Midwives
#   Military
#   Military_Ranks
#   Military_units
#   Millers
#   Misc._items
#   Mistresses_of_Novices
#   Mistresses_of_the_Ships
#   Morat'rakens
#   Mosaada
#   Moshaine
#   Mountains
#   Murandy
#   Murandy_(people)
#   Musara
#   Nakai
#   Naming_redirect
#   Naming_redirects
#   Nations
#   Nations_of_the_Free_Years
#   Neder
#   New_Era
#   New_Era_chronology
#   New_Spring_chapter_summaries
#   Nine_Valleys
#   No_Ajah
#   Nobility
#   Noble_houses
#   Nobles
#   Non-canon
#   Notes_needed
#   Novices
#   Occupations
#   Oceans
#   Ogier
#   Ogier_culture
#   Old_Tongue
#   Old_Tongue_redirects
#   One_Power
#   Online_Forums
#   Organizations
#   Orphan_keepers
#   Other_animals
#   Other_features
#   Other_non-humans
#   Other_notable_buildings
#   POV_character
#   Pages_using_ISBN_magic_links
#   Pages_using_duplicate_arguments_in_template_calls
#   Pages_with_broken_file_links
#   Pages_with_reference_errors
#   Palaces
#   Panarchs
#   Parallels
#   Peddlers
#   Peninsulas
#   People
#   People_of_the_Free_Years
#   Philosophers
#   Philosophy
#   Phrases
#   Places
#   Plains
#   Plants
#   Poets
#   Poisons
#   Politics
#   Prince
#   Prophecies
#   Publishers
#   Quartermasters
#   Queen's_Guards
#   Queens
#   Questioners
#   Races
#   Rahien_Sorei
#   Rand's_Aes_Sedai
#   Rebel_Aes_Sedai
#   Red_Ajah
#   Red_Salt
#   Red_Water
#   Redarms
#   Redirects
#   Reincarnated
#   Reyn
#   Rivers
#   Roads
#   Roofmistresses
#   Royalty
#   Ruins
#   Rulers
#   Ruling_bodies
#   S'redit_handler
#   Sa'angreal
#   Saddlemakers
#   Safer
#   Safer_(people)
#   Saidin
#   Sailmistresses
#   Sailors
#   Saldaea
#   Saldaea_(people)
#   Salt_Flat
#   Scholars
#   Sea_Folk
#   Seamstresses
#   Seanchan
#   Seanchan_(people)
#   Seanchan_animal_handlers
#   Seanchan_animals
#   Seanchan_continent
#   Seanchan_culture
#   Second_Age
#   Secretaries
#   Sedan_Chair_bearers
#   Seekers
#   Seekers_for_Truth
#   Seia_Doon
#   Serai
#   Series_books
#   Servants
#   Serving_girls
#   Sha'mad_Conde
#   Shaarad
#   Shadar_Logoth
#   Shadow
#   Shadowspawn
#   Shae'en_M'taal
#   Shaido
#   Shandalle_(people)
#   Shara
#   Shara_(people)
#   Sharan_(people)
#   Shelan
#   Shiande
#   Shienar
#   Shienar_(people)
#   Shiota_(people)
#   Ship_captains
#   Ships
#   Shorara
#   Short_pages
#   Silversmiths
#   Sitters
#   Slang
#   Slaves
#   Smoke_Water
#   Sniffers
#   So'jhin
#   Soldier_(Asha'man)
#   Soldiers
#   Songs
#   Sovin_Nai
#   Sparkers
#   Special_abilities
#   Special_objects
#   Spine_Ridge
#   Stablemen
#   Statistical_analysis
#   Stewards_of_the_Dragon
#   Stones_River
#   Strength_in_power
#   Sul'dam
#   Sword_form_redirects
#   Sword_forms
#   Sword_instructors
#   Swordmasters
#   Symbols
#   Ta'veren
#   Taardad
#   Taim's_cronies
#   Tain_Shari
#   Taint
#   Talents
#   Talmour_(people)
#   Tar_Valon
#   Tar_Valon_(people)
#   Tarabon
#   Tarabon_(people)
#   Tavernkeepers
#   Taverns
#   Tear
#   Tear_(people)
#   Technology
#   Tel'aran'rhiod
#   Ten_Nations
#   Ter'angreal
#   Thatchers
#   The_Blood
#   The_Dragon_Reborn_chapter_summaries
#   The_Eye_of_the_World_chapter_summaries
#   The_Fires_of_Heaven_chapter_summaries
#   The_Free_Years
#   The_Gathering_Storm_chapter_summaries
#   The_Great_Hunt_chapter_summaries
#   The_Path_of_Daggers_chapter_summaries
#   The_Pattern
#   The_Shadow
#   The_Shadow_Rising_chapter_summaries
#   The_Turned
#   The_Wheel_of_Time
#   Theories
#   Thief-catchers
#   Third_Age
#   Thrones
#   Thugs
#   Time
#   Timeline
#   Timeline_redirects
#   Titles
#   Todo
#   Toman_Head
#   Tomanelle
#   Tova_(people)
#   Tower_Guards
#   Towers_of_Midnight_chapter_summaries
#   Towns
#   Tradition
#   Trees
#   Treesingers
#   Trivia
#   Truthspeakers
#   Tuatha'an
#   Tuatha'an_(people)
#   Two_Rivers
#   Two_Rivers_(people)
#   Two_Spires
#   Unaligned_sisters
#   Unclaimed_territories
#   Unclaimed_territories_(people)
#   Unknown_Ajah
#   Unknown_clan
#   Unknown_gender
#   Unknown_nationality
#   Unknown_occupation
#   Unknown_sept
#   Unknown_society
#   Unknown_status
#   Unnamed_characters
#   Updates_needed
#   Viewers
#   Village_Councilors
#   Villages
#   Wagon_Drivers
#   Warders
#   Warriors
#   Wars
#   Watchmen
#   Wavemistresses
#   Weapons
#   Weavers
#   Weaves
#   Westlands
#   White_Ajah
#   White_Cliff
#   White_Mountain
#   White_Tower
#   Wilders
#   Windfinders
#   Wine
#   Winged_Guard
#   Winter's_Heart_chapter_summaries
#   Wisdoms
#   Wise_Ones
#   Wolfbrothers
#   Wolves
#   Women
#   Women's_Circle
#   Wotwiki_featured_articles
#   Yellow_Ajah
#   Younglings
